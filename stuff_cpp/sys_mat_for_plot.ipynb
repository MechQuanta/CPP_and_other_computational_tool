# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

file_path = 'system_matrix.dat'
# Assuming data is in a structured format like CSV or similar
df = pd.read_csv(file_path, delimiter='\t')
# Process the DataFrame
print(df)
# Out:
#                          1   2   3   4
# 0                   1 0.01 1 -0.394784
# 1            2 0.02 0.996052 -0.777166
# 2              3 0.03 0.98828 -1.14598
# 3             4 0.04 0.976821 -1.50013
# 4             5 0.05 0.961819 -1.83864
# ..                                 ...
# 995  996 9.96 -3.09122e-08 5.99266e-06
# 996   997 9.97 2.90143e-08 5.81659e-06
# 997   998 9.98 8.71803e-08 5.62241e-06
# 998   999 9.99 1.43404e-07 5.41136e-06
# 999    1000 10 1.97518e-07 5.18474e-06
#
# [1000 rows x 1 columns]

# %%
import csv

with open('system_matrix.dat', 'r') as dat_file:
    with open('system_data.csv', 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        for row in dat_file:
            row = [value.strip() for value in row.split('|')]
            csv_writer.writerow(row)

# %%
df_new = pd.read_csv('system_data.csv')

# %%
df_new['2']
# Out:
# 0      1.000000e+00
# 1      9.960520e-01
# 2      9.882800e-01
# 3      9.768210e-01
# 4      9.618190e-01
#            ...
# 995   -3.091220e-08
# 996    2.901430e-08
# 997    8.718030e-08
# 998    1.434040e-07
# 999    1.975180e-07
# Name: 2, Length: 1000, dtype: float64

# %%
plt.scatter(df_new['2'],df_new['3'],label='vector [x y]')

# Set axis limits
plt.xlim(0, 1000)  # Set x-axis range
plt.ylim(0, 1000)   # Set y-axis range


# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("system_data.csv", header=None, names=["Index", "t", "x", "y"])

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(df["x"], df["y"])

# Customize the plot
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of x vs y")
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("system_data.csv", header=None, names=["Index", "t", "x", "y"])

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(df["t"], df["x"])

# Customize the plot
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of x vs y")
plt.grid(True)

# Show the plot
plt.show()

# %%
import csv

with open('damping_diffeq.dat', 'r') as dat_file:
    with open('system_data2.csv', 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        for row in dat_file:
            row = [value.strip() for value in row.split('|')]
            csv_writer.writerow(row)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("system_data2.csv", header=None, names=["Index", "t", "x", "y"])

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(df["x"], df["y"])

# Customize the plot
plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of x vs y")
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("system_data2.csv", header=None, names=["Index", "t", "x", "y"])

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(df["t"], df["x"])

# Customize the plot
plt.xlabel("t")
plt.ylabel("x")
plt.title("Plot of x vs t")
plt.grid(True)

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("system_data2.csv", header=None, names=["Index", "t", "x", "y"])

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(df["t"], df["y"])

# Customize the plot
plt.xlabel("t")
plt.ylabel("y")
plt.title("Plot of x vs y")
plt.grid(True)

# Show the plot
plt.show()
